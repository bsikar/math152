# %% [markdown]
# ## MATH 152 Lab  1

# %% [markdown]
# MATH 152 Lab 1
# Section Number: 571
#
# Members:
#
# * Brighton Sikarskie
# * Alex Krakora
# * Joseph Pham
# * Diego Mendez

# %%
from sympy import *
from sympy.plotting import (plot,plot_parametric)

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### 1a

# %%
a = 1.54
b = 3.78

e = (sin(a) ** 2 + cos(a) ** 2) / (b ** 2 + 1)

print(f"The evaluated expression (sin^2(a) + cos^2(a)) / (b^2 + a) where a is {a} and b is {b} is {e}")
# Out:
# The evaluated expression (sin^2(a) + cos^2(a)) / (b^2 + a) where a is 1.54 and b is 3.78 is 0.0654090683132310

# %% [markdown]
# #### 1b

# %%
a = 1.54
b = 3.78

e = ((sin(a) + cos(a)) ** 2) / (b ** 2 + 1)

print(f"The evaluated expression ((sin(a) + cos(a))^2) / (b^2 + a) where a is {a} and b is {b} is {e}")
# Out:
# The evaluated expression ((sin(a) + cos(a))^2) / (b^2 + a) where a is 1.54 and b is 3.78 is 0.0694352396215374

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### 2a

# %%
x = (3 * pi) / 4

e1 = (sin(x) ** 2)
e2 = (1 - cos(2 * x)) / 2

print(f"The evaluated expression sin^2(x) where x is {x} is {e1}")
print(f"The evaluated expression (1 - cos(2x)) / 2 where x is {x} is {e2}")
print(f"Both solutions are equal: {e1 == e2}")
# Out:
# The evaluated expression sin^2(x) where x is 3*pi/4 is 1/2
# The evaluated expression (1 - cos(2x)) / 2 where x is 3*pi/4 is 1/2
# Both solutions are equal: True

# %% [markdown]
# #### 2b

# %%
x = Symbol('x')
f = sin(x) ** 2 - (1 - cos(2 * x)) / 2
plot(f, (x, 0, 2 * pi))

print("Above is the graph of sin^2(x) - (1 - cos(2x)) / 2")
print("We are unable to get 0 at y = 0 because python is unable to calculate the value of sin^2(x) - (1 - cos(2x)) / 2 at x = 0 without rounding errors")
# Out:
# Above is the graph of sin^2(x) - (1 - cos(2x)) / 2
# We are unable to get 0 at y = 0 because python is unable to calculate the value of sin^2(x) - (1 - cos(2x)) / 2 at x = 0 without rounding errors

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### 3a

# %%
x = Symbol('x')
f = -x ** 3 - 2* x ** 2 + 5 * x
g = x
plot(f, g, (x, -4, 2))
print("Above is the graph of -x^3 - 2x^2 + 5x and x")
print("There are 3 intersections between the two graphs")
# Out:
# Above is the graph of -x^3 - 2x^2 + 5x and x
# There are 3 intersections between the two graphs

# %% [markdown]
# #### 3b

# %%
intercetions = solve(f - g)
intercetions.sort()
print(f"The intersections are at {intercetions}")

# Find the area of the lower half
area_f1 = integrate(f, (x, intercetions[0], intercetions[1]))
area_f2 = integrate(f, (x, intercetions[1], intercetions[2]))
area_g1 = integrate(g, (x, intercetions[0], intercetions[1]))
area_g2 = integrate(g, (x, intercetions[1], intercetions[2]))

e = area_g1 - area_f1 + area_f2 - area_g2
print(f"The area of the lower half is {e.simplify()} which is {e.simplify().evalf()}")
# Out:
# The intersections are at [-sqrt(5) - 1, 0, -1 + sqrt(5)]
# The area of the lower half is 52/3 which is 17.3333333333333

# %% [markdown]
# #### Question 4

# %% [markdown]
# ### 4a

# %%
dx, du, x = symbols('dx du x')
f = 5 * x ** 2 * (x ** 3 - 7) ** (1 / 2)
u = x ** 3 - 7
DU = u.diff(x)
u = Symbol('u')


print(f"The integral of 5x^2(x^3 - 7)(1/2) is {f}")
# Out:
# 5*u**0.5*x**2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2307511/1822999467.py in <module>
#       9 display(f)
#      10
# ---> 11 f = integrate(f)
#      12
#      13 display(f)
#
# ~/.local/lib/python3.10/site-packages/sympy/integrals/integrals.py in integrate(meijerg, conds, risch, heurisch, manual, *args, **kwargs)
#    1562         'manual': manual
#    1563         }
# -> 1564     integral = Integral(*args, **kwargs)
#    1565
#    1566     if isinstance(integral, Integral):
#
# ~/.local/lib/python3.10/site-packages/sympy/integrals/integrals.py in __new__(cls, function, *symbols, **assumptions)
#      94                 active_deprecations_target="deprecated-integrate-poly")
#      95
# ---> 96         obj = AddWithLimits.__new__(cls, function, *symbols, **assumptions)
#      97         return obj
#      98
#
# ~/.local/lib/python3.10/site-packages/sympy/concrete/expr_with_limits.py in __new__(cls, function, *symbols, **assumptions)
#     545     def __new__(cls, function, *symbols, **assumptions):
#     546         from sympy.concrete.summations import Sum
# --> 547         pre = _common_new(cls, function, *symbols,
#     548             discrete=issubclass(cls, Sum), **assumptions)
#     549         if isinstance(pre, tuple):
#
# ~/.local/lib/python3.10/site-packages/sympy/concrete/expr_with_limits.py in _common_new(cls, function, discrete, *symbols, **assumptions)
#      64         free = function.free_symbols
#      65         if len(free) != 1:
# ---> 66             raise ValueError(
#      67                 "specify dummy variables for %s" % function)
#      68         limits, orientation = [Tuple(s) for s in free], 1
#
# ValueError: specify dummy variables for 5*u**0.5*x**2

# %% [markdown]
# ### 4b

# %%
other_f = f
f = 5 * x ** 2 * (x ** 3 - 7) * (1 / 2)
f = integrate(f, x)

print(f"The integral of 5x^2(x^3 - 7)(1/2) is {f}")
print(f"The two integrals are equal: {f == other_f}")
# Out:
# The integral of 5x^2(x^3 - 7)(1/2) is 0.416666666666667*x**6 - 5.83333333333333*x**3
# The two integrals are equal: False

# %% [markdown]
# ### 4c

# %%
#start code here

# %% [markdown]
# ### 4d

# %%
#start code here
